# %%
from STYLEGAN2_1.generator_111 import StyleGan2Generator
import tensorflow as tf

# %%
noise = tf.random.normal(mean=0, stddev=1, shape=(1, 512))
gen = StyleGan2Generator(resolution=32, name='StyleGan2Generator')

# %%
img = gen(noise)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 img = gen(noise)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\miniconda3\envs\tf\lib\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
# ...
